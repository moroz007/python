# %%
a = int(input('введите год: '))

if a % 100 == 0 and not a % 400 == 0:
    print('Обычный')
elif a % 4 == 0:
    print('Високосный')
else:
    print('Обычный')
# Out:
# введите год: 1906
# Обычный
